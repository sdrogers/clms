# %% [markdown]
# ### Test simon's old class to compute isotopes and adduct transformations

# %%
import sys
sys.path.append('../codes')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from VMSfunctions.transformation import *

# %%
transformations = load_from_file('pos_transformations_camera.yml')

# %%
monoisotopic_mass = 169.0851
for t in transformations:
    print(t, t.transform(monoisotopic_mass))
# Out:
# M+H 168.07782354800923
# M+H[C13] 167.07446871020923
# M+H[2C13] 166.07111387240923
# [M+ACN]+H 127.05127444634925
# [M+ACN]+H[C13] 126.04791960854925
# [M+ACN]+H[2C13] 125.04456477074925
# [M+CH3OH]+H 136.05160879734925
# [M+CH3OH]+H[C13] 135.04825395954924
# [M+CH3OH]+H[2C13] 134.04489912174924
# [M+NH3]+H 151.05127444634925
# [M+NH3]+H[C13] 150.04791960854925
# [M+NH3]+H[2C13] 149.04456477074925
# [M+CH2O2]+H 122.07234423952926
# [M+CH2O2]+H[C13] 121.06898940172925
# [M+CH2O2]+H[2C13] 120.06563456392925
# [M-CO]+H 196.07273817010923
# [M-CO]+H[C13] 195.06938333230923
# [M-CO]+H[2C13] 194.06602849450923
# [M-H2O]+H 186.08838823438924
# [M-H2O]+H[C13] 185.08503339658924
# [M-H2O]+H[2C13] 184.08167855878924
# [M-CH2O2]+H 214.08330285648924
# [M-CH2O2]+H[C13] 213.07994801868924
# [M-CH2O2]+H[2C13] 212.07659318088923
# [M-NH3]+H 185.10437264966924
# [M-NH3]+H[C13] 184.10101781186924
# [M-NH3]+H[2C13] 183.09766297406924
# [M-C2H2]+H 194.09347361228924
# ...
